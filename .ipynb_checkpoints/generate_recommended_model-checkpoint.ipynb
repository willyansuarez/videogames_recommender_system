# %% [markdown]
# # Generar data para el modelo recomendación juegos steam

# %%
import pandas as pd

# %%
df_model = pd.read_parquet("archivos_parquet//df_steam_games.parquet")

# %%
df_model.head()
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url  \
# 0      None   None     None  None  None         None  None        None
# 1      None   None     None  None  None         None  None        None
# 2      None   None     None  None  None         None  None        None
# 3      None   None     None  None  None         None  None        None
# 4      None   None     None  None  None         None  None        None
#
#    discount_price specs price  early_access  id  metascore developer  \
# 0             NaN  None  None           NaN NaN        NaN      None
# 1             NaN  None  None           NaN NaN        NaN      None
# 2             NaN  None  None           NaN NaN        NaN      None
# 3             NaN  None  None           NaN NaN        NaN      None
# 4             NaN  None  None           NaN NaN        NaN      None
#
#              user_id      steam_id  \
# 0  76561197970982479  7.656120e+16
# 1            js41637  7.656120e+16
# ...

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120445 entries, 0 to 120444
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   publisher       24073 non-null  object
#  1   genres          28852 non-null  object
#  2   app_name        32133 non-null  object
#  3   title           30085 non-null  object
#  4   url             32135 non-null  object
#  5   release_date    30068 non-null  object
#  6   tags            31972 non-null  object
#  7   reviews_url     32133 non-null  object
#  8   discount_price  225 non-null    float64
#  9   specs           31465 non-null  object
#  10  price           30758 non-null  object
#  11  early_access    32135 non-null  float64
#  12  id              32133 non-null  float64
#  13  metascore       2607 non-null   float64
#  14  developer       28836 non-null  object
#  15  user_id         88310 non-null  object
#  16  steam_id        88310 non-null  float64
# ...

# %%
df_model.columns
# Out:
# Index(['publisher', 'genres', 'app_name', 'title', 'url', 'release_date',
#        'tags', 'reviews_url', 'discount_price', 'specs', 'price',
#        'early_access', 'id', 'metascore', 'developer', 'user_id', 'steam_id',
#        'items', 'items_count'],
#       dtype='object')

# %%
# eliminar columnas innecesarias
df_model.drop([
       'title', 'url', 'release_date', 'reviews_url', 'discount_price', 'price',
       'early_access', 'metascore', 'developer', 'user_id', 'steam_id',
       'items', 'items_count', 'publisher'
    ], axis=1, inplace=True)

# %%
# algunas comprobaciones
df_model.head()
df_model.shape
df_model.isnull().sum()
# Out:
# genres      91593
# app_name    88312
# tags        88473
# specs       88980
# id          88312
# dtype: int64

# %%
df_model.duplicated().sum()
# Out:
# 88311

# %%
# elimino nulos
df_model.dropna(inplace=True)

# %%
# elimino duplicados
df_model.drop_duplicates(inplace=True)

# %%
# visualizar algunos datos
df_model['genres']
# Out:
# 88310     ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 88311          ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 88312     ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 88313                     ['Action', 'Adventure', 'Casual']
# 88315                 ['Action', 'Adventure', 'Simulation']
#                                 ...
# 120439           ['Action', 'Adventure', 'Casual', 'Indie']
# 120440        ['Casual', 'Indie', 'Simulation', 'Strategy']
# 120441                      ['Casual', 'Indie', 'Strategy']
# 120442                    ['Indie', 'Racing', 'Simulation']
# 120443                                  ['Casual', 'Indie']
# Name: genres, Length: 28541, dtype: object

# %%
# Verificar si una fila contiene caracteres extraños o en idiomas diferentes al inglés
# se puede hacer por columna, pero se consideró mejor por filas
row_contains = df_model.apply(lambda row: row.str.contains('[^\x00-\x7F]').any(), axis=1)

# %%
# veerifico la cantidad
row_contains[row_contains == True].count()
# Out:
# 3001

# %%
# eliminar todas esas filas
df_model = df_model[~row_contains]

# %%
# reset del índice
df_model.reset_index(drop=True, inplace=True)

# %%
# compruebo tamaño y datos
df_model.shape
df_model.head()
# Out:
#    index                                           genres  \
# 0  88310    [Action, Casual, Indie, Simulation, Strategy]
# 1  88311               [FreetoPlay, Indie, RPG, Strategy]
# 2  88312  [Casual, FreetoPlay, Indie, Simulation, Sports]
# 3  88315                  [Action, Adventure, Simulation]
# 4  88316          [FreetoPlay, Indie, Simulation, Sports]
#
#                        app_name  \
# 0           Lost Summoner Kitty
# 1                     Ironbound
# 2       Real Pool 3D - Poolians
# 3         Battle Royale Trainer
# 4  SNOW - All Access Basic Pass
#
#                                                 tags  \
# 0      [Strategy, Action, Indie, Casual, Simulation]
# 1  [FreetoPlay, Strategy, Indie, RPG, CardGame, T...
# 2  [FreetoPlay, Simulation, Sports, Casual, Indie...
# 3  [Action, Adventure, Simulation, FPS, Shooter, ...
# 4            [FreetoPlay, Indie, Simulation, Sports]
#
#                                                specs        id
# ...

# %%
# verificar como están los valores en las columnas escogidas, al parecer son tipo listas
# de listas, al ver el tipo de datos es object, si se intenta ingresar al segundo elemento
# de la supuesta lista en caso de haber mas de un elemento, solo devuelve una letra
df_model['genres'][0]
# Out:
# 'Casual'

# %%
# aplico métodos de str por columna, replace y strip
df_model['genres'] = df_model['genres'].apply(lambda gene: [g.strip().replace("'", "").replace("[", "").replace("]", "").replace(" ", "") for g in gene.split(",")])
df_model['tags'] = df_model['tags'].apply(lambda gene: [g.strip().replace("'", "").replace("[", "").replace("]", "").replace(" ", "") for g in gene.split(",")])
df_model['specs'] = df_model['specs'].apply(lambda gene: [g.strip().replace("'", "").replace("[", "").replace("]", "").replace("-", "").replace(" ", "") for g in gene.split(",")])

# %%
# uno las columnas en una sola
df_model["tags_2"] = df_model['genres'] + df_model['tags'] + df_model['specs']

# %%
# verifico los datos
df_model.head()
# Out:
#    index                                           genres  \
# 0  88310    [Action, Casual, Indie, Simulation, Strategy]
# 1  88311               [FreetoPlay, Indie, RPG, Strategy]
# 2  88312  [Casual, FreetoPlay, Indie, Simulation, Sports]
# 3  88315                  [Action, Adventure, Simulation]
# 4  88316          [FreetoPlay, Indie, Simulation, Sports]
#
#                        app_name  \
# 0           Lost Summoner Kitty
# 1                     Ironbound
# 2       Real Pool 3D - Poolians
# 3         Battle Royale Trainer
# 4  SNOW - All Access Basic Pass
#
#                                                 tags  \
# 0      [Strategy, Action, Indie, Casual, Simulation]
# 1  [FreetoPlay, Strategy, Indie, RPG, CardGame, T...
# 2  [FreetoPlay, Simulation, Sports, Casual, Indie...
# 3  [Action, Adventure, Simulation, FPS, Shooter, ...
# 4            [FreetoPlay, Indie, Simulation, Sports]
#
#                                                specs        id  \
# ...

# %%
# ver columnas
df_model.columns
# Out:
# Index(['index', 'genres', 'app_name', 'tags', 'specs', 'id', 'tags_2'], dtype='object')

# %%
# # eliminar columnas
df_model.drop(['index', 'genres', 'tags', 'specs'], axis=1, inplace=True)

# %%
df_model.head()
# Out:
#                        app_name        id  \
# 0           Lost Summoner Kitty  761140.0
# 1                     Ironbound  643980.0
# 2       Real Pool 3D - Poolians  670290.0
# 3         Battle Royale Trainer  772540.0
# 4  SNOW - All Access Basic Pass  774276.0
#
#                                               tags_2
# 0  [Action, Casual, Indie, Simulation, Strategy, ...
# 1  [FreetoPlay, Indie, RPG, Strategy, FreetoPlay,...
# 2  [Casual, FreetoPlay, Indie, Simulation, Sports...
# 3  [Action, Adventure, Simulation, Action, Advent...
# 4  [FreetoPlay, Indie, Simulation, Sports, Freeto...

# %%
# cambio el tipo de dato
df_model_recommend['id'] = df_model_recommend['id'].astype(int)

# %%
# exportar el dataset
df_model_recommend = df_model.to_parquet("df_model_recommend.parquet")
