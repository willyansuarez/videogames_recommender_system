# %% [markdown]
# # ETL y EDA archivo steam_games

# %%
# importar módulos
# import io
# import gzip
# import ast
import pandas as pd
# import json
# from google.colab import files
import fastparquet
pd.set_option('display.max_columns', 500)
# pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### **Carga del datasets**

# %%
# cargar el dataset
df_steam_games = pd.read_parquet("archivos_originales//df_steam_games.parquet")

# %%
df_steam_games.head(2)
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url  \
# 0      None   None     None  None  None         None  None        None
# 1      None   None     None  None  None         None  None        None
#
#    discount_price specs price  early_access  id  metascore developer  \
# 0             NaN  None  None           NaN NaN        NaN      None
# 1             NaN  None  None           NaN NaN        NaN      None
#
#              user_id      steam_id  \
# 0  76561197970982479  7.656120e+16
# 1            js41637  7.656120e+16
#
#                                                items  items_count
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...        277.0
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...        888.0

# %%
# función para obtener datos varios de los dataframe(info, describe, null, duplicated)
def print_df_info(df):

    print("** Info - Información general **")
    print(df.info())

    print("=======================================================")

    print("** Shape **")
    print(f"Filas: {df.shape[0]} - Columnas: {df.shape[1]}")

    print("=======================================================")

    print("** Describe - Estadísticas resumidas **")
    print(df.describe().T)

    print("=======================================================")

    print("** NaN - Nulos **")
    print(df.isna().sum())

    print("=======================================================")
    print("** Duplicated - Duplicados **")
    print(df.duplicated().sum())

# %%
print_df_info(df_steam_games)
# Out:
# ** Info - Información general **
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120445 entries, 0 to 120444
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   publisher       24073 non-null  object
#  1   genres          28852 non-null  object
#  2   app_name        32133 non-null  object
#  3   title           30085 non-null  object
#  4   url             32135 non-null  object
#  5   release_date    30068 non-null  object
#  6   tags            31972 non-null  object
#  7   reviews_url     32133 non-null  object
#  8   discount_price  225 non-null    float64
#  9   specs           31465 non-null  object
#  10  price           30758 non-null  object
#  11  early_access    32135 non-null  float64
#  12  id              32133 non-null  float64
#  13  metascore       2607 non-null   float64
#  14  developer       28836 non-null  object
#  15  user_id         88310 non-null  object
#  16  steam_id        88310 non-null  float64
#  17  items           88310 non-null  object
#  18  items_count     88310 non-null  float64
# dtypes: float64(6), object(13)
# memory usage: 18.4+ MB
# None
# =======================================================
# ** Shape **
# Filas: 120445 - Columnas: 19
# =======================================================
# ** Describe - Estadísticas resumidas **
#                   count          mean           std           min  \
# discount_price    225.0  1.193053e+01  1.749264e+01  4.900000e-01
# early_access    32135.0  6.058814e-02  2.385770e-01  0.000000e+00
# id              32133.0  4.517574e+05  1.827140e+05  1.000000e+01
# metascore        2607.0  7.225547e+01  1.083352e+01  2.000000e+01
# steam_id        88310.0  7.656120e+16  3.931726e+07  7.656120e+16
# items_count     88310.0  5.835363e+01  1.223121e+02  0.000000e+00
#
#                          25%           50%           75%           max
# discount_price  1.390000e+00  4.190000e+00  2.266000e+01  1.399900e+02
# early_access    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# id              3.292800e+05  4.520600e+05  5.934000e+05  2.028850e+06
# metascore       6.600000e+01  7.400000e+01  8.000000e+01  9.600000e+01
# steam_id        7.656120e+16  7.656120e+16  7.656120e+16  7.656120e+16
# items_count     3.000000e+00  2.600000e+01  7.300000e+01  7.762000e+03
# =======================================================
# ** NaN - Nulos **
# publisher          96372
# genres             91593
# app_name           88312
# title              90360
# url                88310
# release_date       90377
# tags               88473
# reviews_url        88312
# discount_price    120220
# specs              88980
# price              89687
# early_access       88310
# id                 88312
# metascore         117838
# developer          91609
# user_id            32135
# steam_id           32135
# items              32135
# items_count        32135
# dtype: int64
# =======================================================
# ** Duplicated - Duplicados **
# 657

# %%
# columnas
df_steam_games.columns
# Out:
# Index(['publisher', 'genres', 'app_name', 'title', 'url', 'release_date',
#        'tags', 'reviews_url', 'discount_price', 'specs', 'price',
#        'early_access', 'id', 'metascore', 'developer', 'user_id', 'steam_id',
#        'items', 'items_count'],
#       dtype='object')

# %%
# eliminar columnas
df_steam_games.drop(
    [
        "publisher", "app_name", "title", "url", "tags", "reviews_url", "discount_price", "specs", "early_access", "metascore",
        "user_id", "steam_id", "items", "items_count"
    ], axis=1, inplace=True)

# %%
df_steam_games.shape
# Out:
# (120445, 5)

# %%
# eliminar duplicados
df_steam_games.drop_duplicates(inplace=True)

# %%
# eliminar primera fila, esta se crea despues de eliminar duplicados
df_steam_games = df_steam_games.drop([0])

# %%
# verifico la eliminación de la fila
df_steam_games.head(2)
# Out:
#                                                   genres release_date  \
# 88310  ['Action', 'Casual', 'Indie', 'Simulation', 'S...   2018-01-04
# 88311       ['Free to Play', 'Indie', 'RPG', 'Strategy']   2018-01-04
#
#               price        id         developer
# 88310          4.99  761140.0         Kotoshiro
# 88311  Free To Play  643980.0  Secret Level SRL

# %%
# reset del índice
df_steam_games.reset_index(drop=True, inplace=True)

# %%
# extraer el año
df_steam_games['year'] = df_steam_games['release_date'].str.extract(r'(\d{4})')

# %%
df_steam_games.head()
# Out:
#                                               genres release_date  \
# 0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...   2018-01-04
# 1       ['Free to Play', 'Indie', 'RPG', 'Strategy']   2018-01-04
# 2  ['Casual', 'Free to Play', 'Indie', 'Simulatio...   2017-07-24
# 3                  ['Action', 'Adventure', 'Casual']   2017-12-07
# 4                                               None         None
#
#           price        id         developer  year
# 0          4.99  761140.0         Kotoshiro  2018
# 1  Free To Play  643980.0  Secret Level SRL  2018
# 2  Free to Play  670290.0      Poolians.com  2017
# 3          0.99  767400.0              彼岸领域  2017
# 4          2.99  773570.0              None   NaN

# %%
# eliminar nulos columna price - los valores nan, none no se consideran como contenido Free
df_steam_games[df_steam_games["price"].isnull()]
df_steam_games.dropna(subset=["price"], inplace=True)
# Out:
# Empty DataFrame
# Columns: [genres, release_date, price, id, developer, year]
# Index: []

# %%
# ver cantidad de Free, Free To Play y Free to Play
print(df_steam_games[df_steam_games["price"] == "Free"].count().sum())
print(df_steam_games[df_steam_games["price"] == "Free To Play"].count().sum())
print(df_steam_games[df_steam_games["price"] == "Free to Play"].count().sum())
# Out:
# 4598
# 2403
# 2930

# %%
# eliminar espacios en blanco y extraer la palabra Free para estandarizar el contenido
df_steam_games['price'] = df_steam_games['price'].str.strip()
df_steam_games['price'] = df_steam_games['price'].str.replace(' To Play', '')
df_steam_games['price'] = df_steam_games['price'].str.replace(' to Play', '')

# %%
# Verificar qué filas contienen letras
rows_with_letters = df_steam_games['price'].apply(lambda x: any(c.isalpha() for c in str(x)))

# Contar cuántas filas contienen letras
count_letters = sum(rows_with_letters)

print(f"El número de filas que contienen letras es: {count_letters}")
# Out:
# El número de filas que contienen letras es: 1910

# %%
# Filtrar las filas que contienen letras en la columna "price"
rows_with_letters = df_steam_games[df_steam_games['price'].str.contains('[a-zA-Z]', regex=True)]

# Imprimir las filas que contienen letras en la columna "price"
rows_with_letters[rows_with_letters.price != "Free"]
# print(rows_with_letters.to_string())
# Out:
#                                                   genres release_date  \
# 920                                            ['Indie']   2012-04-06
# 921                                  ['Indie', 'Casual']   2012-04-06
# 969     ['Free to Play', 'Massively Multiplayer', 'RPG']   2012-06-06
# 981    ['Action', 'Adventure', 'Free to Play', 'Massi...   2012-06-25
# 2405                                       ['Utilities']   2014-09-19
# 2871                               ['Indie', 'Strategy']   2014-11-20
# 3314                   ['Action', 'Free to Play', 'RPG']   2008-01-18
# 3832   ['Adventure', 'Casual', 'Indie', 'RPG', 'Simul...   2015-06-10
# 3918                                           ['Indie']   2015-07-02
# 4026                                 ['Casual', 'Indie']   2015-07-20
# 5589                                          ['Action']   2016-03-11
# 13947                  ['Action', 'Free to Play', 'RPG']   2012-10-31
# 22733                                       ['Strategy']   2016-06-10
# 24999                                               None   2015-11-10
# 25000                                               None   2015-11-10
# 26216     ['Adventure', 'Casual', 'Indie', 'Simulation']   2015-06-24
# 26903  ['Animation &amp; Modeling', 'Design &amp; Ill...   2008-01-01
# 28313                                         ['Action']   2014-09-23
# 28314                                         ['Action']   2014-09-23
# 29365                                               None   2014-03-19
# 30379  ['Animation &amp; Modeling', 'Design &amp; Ill...   2013-01-25
# 30909                                          ['Indie']   2012-06-12
# 31837                                         ['Casual']   2007-09-11
#
#                                price        id  \
# 920                        Free Demo  213530.0
# 921                        Free Demo  213390.0
# 969                   Play for Free!  212500.0
# 981                   Play for Free!  206480.0
# 2405                     Install Now  268850.0
# 2871   Play WARMACHINE: Tactics Demo  253510.0
# 3314                        Free Mod  349480.0
# 3832                   Install Theme  370880.0
# 3918                     Third-party  362970.0
# 4026                        Play Now  345040.0
# 5589       Free HITMAN™ Holiday Pack  236870.0
# 13947                       Free Mod  632730.0
# 22733                  Play the Demo  438920.0
# 24999            Starting at $499.00  353420.0
# 25000            Starting at $449.00  353390.0
# 26216                       Play Now  383860.0
# 26903                    Free to Try  366530.0
# 28313                       Free Mod  324850.0
# 28314                       Free Mod  324830.0
# 29365                     Free Movie  245550.0
# 30379                    Free to Use  227240.0
# 30909                      Free Demo  213490.0
# 31837                    Third-party    3483.0
#
#                                                developer  year
# 920                                                  TAO  2012
# 921                                        BitSits Games  2012
# 969                            Standing Stone Games, LLC  2012
# 981                            Standing Stone Games, LLC  2012
# 2405                                                EVGA  2014
# 2871                                    WhiteMoon Dreams  2014
# 3314                         Ascension Entertainment LLC  2008
# 3832                                  Stolen Couch Games  2015
# 3918                                     Polar Bunny Ltd  2015
# 4026                              CorypheeSoft,DigitalEZ  2015
# 5589   IO Interactive A/S,Feral Interactive (Linux),F...  2016
# 13947                                               PLut  2012
# 22733                              Boomzap Entertainment  2016
# 24999                                               None  2015
# 25000                                               None  2015
# 26216                                          Zeiva Inc  2015
# 26903                                 Grzegorz Slazinski  2008
# 28313              RO2/RS Community,Tripwire Interactive  2014
# 28314              RO2/RS Community,Tripwire Interactive  2014
# 29365                                               None  2014
# 30379                                             Scirra  2013
# 30909                                   Blackcow Studios  2012
# 31837                                 PopCap Games, Inc.  2007

# %%
# reemplazar Free por cero(0) - los valores nan, none no se consideraron como contenido Free
# algunos valores se consideran Free tales como, 0 Demo, Play for 0!, etc
df_steam_games['price'] = df_steam_games['price'].str.replace('Free', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('0 Demo', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('Play for 0!', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('Play WARMACHINE: Tactics Demo', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('0 Mod', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('0 HITMAN™ Holiday Pack', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('Play the Demo', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('0 to Try', '0')
df_steam_games['price'] = df_steam_games['price'].str.replace('0 to Use', '0')

# %%
# se detectaron otras cadenas alphanuméricas de las cuales algunas se consideran Free y
# las otras se eliminan
df_steam_games = df_steam_games.drop([2405, 3314, 3832, 3918, 31837, 4026, 26216, 24999, 25000, 29365])

# %%
df_steam_games[df_steam_games['price'] == "Install Now"]
df_steam_games.loc[29365, :]
# Out:
# genres                None
# release_date    2014-03-19
# price              0 Movie
# id                245550.0
# developer             None
# year                  2014
# Name: 29365, dtype: object

# %%
# cambio del tipo de dato de la columna
df_steam_games['price'] = df_steam_games['price'].astype(float)

# %%
# eliminar la columna release_date, solo se necesita el año
df_steam_games.drop(["release_date"], axis=1, inplace=True)

# %%
# verifico
df_steam_games.head()
# Out:
#                                               genres  price        id  \
# 0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...   4.99  761140.0
# 1       ['Free to Play', 'Indie', 'RPG', 'Strategy']   0.00  643980.0
# 2  ['Casual', 'Free to Play', 'Indie', 'Simulatio...   0.00  670290.0
# 3                  ['Action', 'Adventure', 'Casual']   0.99  767400.0
# 4                                               None   2.99  773570.0
#
#           developer  year
# 0         Kotoshiro  2018
# 1  Secret Level SRL  2018
# 2      Poolians.com  2017
# 3              彼岸领域  2017
# 4              None   NaN

# %%
print(df_steam_games.isnull().sum())
df_steam_games[df_steam_games['genres'].isnull()]
# Out:
# genres       3133
# price           0
# id              2
# developer    3154
# year         1940
# dtype: int64
#       genres  price        id developer  year
# 4       None   2.99  773570.0      None  None
# 11      None   0.00  724910.0      None  None
# 19      None   4.99  772590.0      None  None
# 20      None   2.99  640250.0      None  None
# 22      None   0.99  711440.0      None  None
# ...      ...    ...       ...       ...   ...
# 32117   None   3.99  775640.0      None  2018
# 32118   None   3.99  777930.0      None  2018
# 32119   None   4.99  775370.0      None  2016
# 32120   None   0.00  777950.0      None  2018
# 32133   None   4.99  681550.0      None   NaN
#
# [3133 rows x 5 columns]

# %%
df_steam_games.dropna(subset=["genres"], inplace=True)
df_steam_games.isnull().sum()
# Out:
# genres         0
# price          0
# id             1
# developer    155
# year           7
# dtype: int64

# %%
df_steam_games.dropna(subset=["developer"], inplace=True)
df_steam_games.isnull().sum()
# Out:
# genres       0
# price        0
# id           1
# developer    0
# year         7
# dtype: int64

# %%
df_steam_games.dropna(subset=["year"], inplace=True)
df_steam_games.isnull().sum()
# Out:
# genres       0
# price        0
# id           1
# developer    0
# year         0
# dtype: int64

# %%
df_steam_games.dropna(subset=["id"], inplace=True)
df_steam_games.isnull().sum()
# Out:
# genres       0
# price        0
# id           0
# developer    0
# year         0
# dtype: int64

# %%
df_steam_games.shape
# Out:
# (27451, 5)

# %%
df_steam_games.head()
# Out:
#                                               genres  price        id  \
# 0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...   4.99  761140.0
# 1       ['Free to Play', 'Indie', 'RPG', 'Strategy']   0.00  643980.0
# 2  ['Casual', 'Free to Play', 'Indie', 'Simulatio...   0.00  670290.0
# 3                  ['Action', 'Adventure', 'Casual']   0.99  767400.0
# 5              ['Action', 'Adventure', 'Simulation']   3.99  772540.0
#
#              developer  year
# 0            Kotoshiro  2018
# 1     Secret Level SRL  2018
# 2         Poolians.com  2017
# 3                 彼岸领域  2017
# 5  Trickjump Games Ltd  2018

# %%
df_steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27451 entries, 0 to 32132
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   genres     27451 non-null  object
#  1   price      27451 non-null  float64
#  2   id         27451 non-null  float64
#  3   developer  27451 non-null  object
#  4   year       27451 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 1.3+ MB

# %%
# cambiar el tipo de dato de la columna id y year
df_steam_games['id'] = df_steam_games['id'].astype(int)
df_steam_games['year'] = df_steam_games['year'].astype(int)

# %%
# cambiar el nombre columna
df_steam_games = df_steam_games.rename(columns={'id':'item_id'})

# %%
# reset del índice
df_steam_games.reset_index(drop=True, inplace=True)

# %%
df_steam_games.head(2)
# Out:
#                                               genres  price  item_id  \
# 0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...   4.99   761140
# 1       ['Free to Play', 'Indie', 'RPG', 'Strategy']   0.00   643980
#
#           developer  year
# 0         Kotoshiro  2018
# 1  Secret Level SRL  2018

# %%
# exportar a parquet ya limpio el archivo
df_steam_games_2 = df_steam_games.to_parquet("datasets/df_steam_games_2.parquet")
