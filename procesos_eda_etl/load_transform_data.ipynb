# %% [markdown]
# # Carga de Archivos
# * steam_games.json.gz
# * user_reviews.json.gz
# * users_items.json.gz

# %%
# importar librerias
# import io
import gzip
import ast
import pandas as pd
import json
import fastparquet

# %% [markdown]
# Carga del archivo steam_games, para exportarlo a csv y luego a parquet, esto para reducir el tamaño
# y agilizar la carga de los datos.
# Primero se exporta a csv ya que el archivo presenta algunos problemas, que pudieron generarse al
# momento de construir el archivo.

# %%
# carga del archivo steam_games
path_file = ("archivos_originales/steam_games.json.gz")
# path_file = ("/content/drive/MyDrive/datasets/steam_files/steam_games.json.gz")
df_steam_games = pd.read_json(path_file, compression="gzip", lines=True)

# %%
# visualizar el dataframe
df_steam_games.head(2)
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url  \
# 0      None   None     None  None  None         None  None        None
# 1      None   None     None  None  None         None  None        None
#
#    discount_price specs price  early_access  id metascore developer  \
# 0             NaN  None  None           NaN NaN      None      None
# 1             NaN  None  None           NaN NaN      None      None
#
#              user_id      steam_id  \
# 0  76561197970982479  7.656120e+16
# 1            js41637  7.656120e+16
#
#                                                items  items_count
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...        277.0
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...        888.0

# %%
# exportar a csv
df_steam_games = df_steam_games.to_csv("archivos_csv/df_steam_games.csv")

# %%
# carga del archivo csv de steam_games
df_steam_games = pd.read_csv("archivos_csv/df_steam_games.csv", low_memory=False, index_col=0)
# df_steam_games = pd.read_csv("/content/drive/MyDrive/datasets/steam_files/df_steam_games.csv", low_memory=False, index_col=0)

# %%
# visualizar el archivo
df_steam_games.head(2)
# Out:
#   publisher genres app_name title  url release_date tags reviews_url  \
# 0       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 1       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
#
#    discount_price specs price  early_access  id  metascore developer  \
# 0             NaN   NaN   NaN           NaN NaN        NaN       NaN
# 1             NaN   NaN   NaN           NaN NaN        NaN       NaN
#
#              user_id      steam_id  \
# 0  76561197970982479  7.656120e+16
# 1            js41637  7.656120e+16
#
#                                                items  items_count
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...        277.0
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...        888.0

# %%
# exportar a parquet
df_steam_games = df_steam_games.to_parquet("archivos_parquet/df_steam_games.parquet")

# %%
# leer el archivo parquet
df_steam_games = pd.read_parquet("archivos_parquet/df_steam_games.parquet")
# df_steam_games = pd.read_parquet("/content/drive/MyDrive/datasets/steam_files/df_steam_games.parquet")

# %%
# visualizar
df_steam_games.head(2)
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url  \
# 0      None   None     None  None  None         None  None        None
# 1      None   None     None  None  None         None  None        None
#
#    discount_price specs price  early_access  id  metascore developer  \
# 0             NaN  None  None           NaN NaN        NaN      None
# 1             NaN  None  None           NaN NaN        NaN      None
#
#              user_id      steam_id  \
# 0  76561197970982479  7.656120e+16
# 1            js41637  7.656120e+16
#
#                                                items  items_count
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...        277.0
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...        888.0

# %% [markdown]
# **Fin del tratamiento del archivo steam_games**

# %% [markdown]
# ### Tramiento del archivo user_reviews

# %%
# carga del archivo user_reviews
path_file = "archivos_originales/user_reviews.json.gz"
# path_file = "/content/drive/MyDrive/datasets/steam_files/user_reviews.json.gz"
def read_data_json(path_file):
    with gzip.open(path_file, "rt", encoding="utf-8") as file:
        return [ast.literal_eval(line.strip()) for line in file]

# %%
# lectura de la data
data = read_data_json()

# %%
# construir el dataframe
df_user_reviews = pd.DataFrame(data)

# %%
# ver y verificar la creación del registro
df_user_reviews.head(2)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...

# %%
# exportar a parquet
df_user_reviews = df_user_reviews.to_parquet("archivos_parquet/df_user_reviews.parquet")

# %%
# carga del archivo para verificar
df_user_reviews = pd.read_parquet("archivos_parquet/df_user_reviews.parquet")

# %%
# visualizar
df_user_reviews.head(2)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
#
#                                              reviews
# 0  [{'funny': '', 'helpful': 'No ratings yet', 'i...
# 1  [{'funny': '', 'helpful': '15 of 20 people (75...

# %% [markdown]
# **Fin tratamiento archivo *user_reviews***

# %% [markdown]
# ### Comienzo tratamiento archivo users_items

# %%
# carga del archivo users_items
path_to_file = "archivos_originales/users_items.json.gz"
# path_to_file = "/content/drive/MyDrive/datasets/steam_files/users_items.json.gz"
def read_data_json(path_to_file):
    with gzip.open(path_to_file, "rt", encoding="utf-8") as file:
        return [ast.literal_eval(line.strip()) for line in file]

# %%
# lectura de la data
data_2 = read_data_json(path_to_file)

# %%
# construir el dataframe
df_users_items = pd.DataFrame(data_2)

# %%
# verificar el dataframe
df_users_items.head(2)
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...

# %%
# exportar a parquet
df_users_items = df_users_items.to_parquet("archivos_parquet/df_users_items.parquet")

# %%
# carga del archivo para verificación 
df_users_items = pd.read_parquet("archivos_parquet/df_users_items.parquet")
# df_users_items = pd.read_parquet("/content/drive/MyDrive/datasets/steam_files/df_users_items.parquet")

# %%
# verificar información
df_users_items.head(2)
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...

# %% [markdown]
# **Fin tratamiento del archivo users_items**
